# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
project = pd.read_csv('C:\Users\Austin\Desktop\Virginia Tech\CS 3654\CMDA\CollegeOffense.csv')

# %%
project.head()
# Out:
#    RK           TEAM   YDS  YDS/G  PASS  P YDS/G  RUSH  R YDS/G  PTS  PTS/G
# 0   1      Texas A&M  2450    613  1620    405.0   830    207.5  221   55.3
# 1   2       Marshall  2387    597  1243    310.8  1144    286.0  182   45.5
# 2   3        Arizona  2375    594  1463    365.8   912    228.0  155   38.8
# 3   4        Alabama  2350    588  1343    335.8  1007    251.8  168   42.0
# 4   5  East Carolina  2326    582  1568    392.0   758    189.5  173   43.3

# %%
hist = project.YDS.hist(bins = 7)
plt.title("Histogram")
# Out:
# The history saving thread hit an unexpected error (OperationalError('disk I/O error',)).History will not be written to the database.

# %%
density = project.YDS.plot(kind = 'kde')
plt.title("Density Plot")

# %%
bar = project.YDS.plot(kind = 'bar')
plt.title("Bar Graph")

# %%
bar2 = project.div(project.sum(1).astype(float), axis = 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-e574a50c3c22> in <module>()
# ----> 1 bar2 = project.div(project.sum(1).astype(float), axis = 1)
#
# C:\Users\Austin\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\core\ops.pyc in f(self, other, axis, level, fill_value)
#     769             return self._combine_frame(other, na_op, fill_value, level)
#     770         elif isinstance(other, pd.Series):
# --> 771             return self._combine_series(other, na_op, fill_value, axis, level)
#     772         elif isinstance(other, (list, tuple)):
#     773             if axis is not None and self._get_axis_name(axis) == 'index':
#
# C:\Users\Austin\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\core\frame.pyc in _combine_series(self, other, func, fill_value, axis, level)
#    2937                 return self._combine_match_index(other, func, level=level, fill_value=fill_value)
#    2938             else:
# -> 2939                 return self._combine_match_columns(other, func, level=level, fill_value=fill_value)
#    2940         return self._combine_series_infer(other, func, level=level, fill_value=fill_value)
#    2941
#
# C:\Users\Austin\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\core\frame.pyc in _combine_match_columns(self, other, func, level, fill_value)
#    2976
#    2977         new_data = left._data.eval(
# -> 2978             func=func, other=right, axes=[left.columns, self.index])
#    2979         return self._constructor(new_data)
#    2980
#
# C:\Users\Austin\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\core\internals.pyc in eval(self, **kwargs)
#    2211
#    2212     def eval(self, **kwargs):
# -> 2213         return self.apply('eval', **kwargs)
#    2214
#    2215     def setitem(self, **kwargs):
#
# C:\Users\Austin\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\core\internals.pyc in apply(self, f, axes, filter, do_integrity_check, **kwargs)
#    2190                                                  copy=align_copy)
#    2191
# -> 2192             applied = getattr(b, f)(**kwargs)
#    2193
#    2194             if isinstance(applied, list):
#
# C:\Users\Austin\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\core\internals.pyc in eval(self, func, other, raise_on_error, try_cast)
#     864         # get the result
#     865         try:
# --> 866             result = get_result(other)
#     867
#     868         # if we have an invalid shape/broadcast error
#
# C:\Users\Austin\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\core\internals.pyc in get_result(other)
#     848         # get the result, may need to transpose the other
#     849         def get_result(other):
# --> 850             return self._try_coerce_result(func(values, other))
#     851
#     852         # error handler if we have an issue operating with the function
#
# C:\Users\Austin\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\core\ops.pyc in na_op(x, y)
#     747                 mask = notnull(xrav) & notnull(yrav)
#     748                 xrav = xrav[mask]
# --> 749                 yrav = yrav[mask]
#     750                 if np.prod(xrav.shape) and np.prod(yrav.shape):
#     751                     result[mask] = op(xrav, yrav)
#
# ValueError: too many boolean indices

# %%
bar3 = bar2.plot(kind = 'bar', stacked = TRUE)
plt.title("Side by side bar graph")

# %%
scatter = plt.scatter(project.YDS, project.RUSH)
plt.title("Scatterplot")

# %%
hist.savefig('hist.png', dpi=400, bbox_inches='tight')
density.savefig('density.png', dpi=400, bbox_inches='tight')
bar.savefig('bar.png', dpi=400, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-f0b294aef109> in <module>()
# ----> 1 hist.savefig('hist.png', dpi=400, bbox_inches='tight')
#       2 density.savefig('density.png', dpi=400, bbox_inches='tight')
#       3 bar.savefig('bar.png', dpi=400, bbox_inches='tight')
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'

# %%
bar3.savefig('bar3.png', dpi=400, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-73ccabd834b1> in <module>()
# ----> 1 bar3.savefig('bar3.png', dpi=400, bbox_inches='tight')
#
# NameError: name 'bar3' is not defined

# %%
scatter.savefig('scatter.png', dpi=400, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-e3c0f5ecba92> in <module>()
# ----> 1 scatter.savefig('scatter.png', dpi=400, bbox_inches='tight')
#
# AttributeError: 'PathCollection' object has no attribute 'savefig'
